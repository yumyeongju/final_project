# %% [markdown]
# # 주제 : 성별에 따른 문화예술 참여율과 삶의 만족도 간의 상관관계

# %% [markdown]
# **데이터 관찰**
#
# ---

# %%
#한국어 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
#필요한 라이브러리 임포트
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#한국어 폰트 설정 / 한국어 마이너스 설정
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumGothic')

#시각화 스타일 설정
sns.set_palette("husl")

# %%
#데이터셋 불러오기1

#문화예술_및_스포츠관람현황_시도 데이터
file_path1 = '/content/문화예술_및_스포츠관람현황_시도__20250420202622.xlsx'
culture_data = pd.read_excel(file_path1)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#데이터셋 불러오기2

#삶의_만족도_시도 데이터
file_path2 = '/content/삶의_만족도_시도__20250420202702.xlsx'
life_data = pd.read_excel(file_path2)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
culture_data
# Out:
#     행정구역별(1)  특성별(1)  특성별(2)   2011   2011.1        2011.2            2011.3  \
# 0   행정구역별(1)  특성별(1)  특성별(2)  계 (%)  관람함 (%)  관람횟수(평균) (회)  - 음악·연주회·콘서트 (%)
# 1         전국      전체       계    100     58.6           8.4              25.2
# 2        NaN      성별      남자    100       58           8.2              21.4
# 3        NaN     NaN      여자    100     59.2           8.7              28.7
# 4      서울특별시      전체       계    100       67           9.7              29.8
# 5        NaN      성별      남자    100     65.7           9.3              25.3
# 6        NaN     NaN      여자    100     68.3            10              33.9
# 7      부산광역시      전체       계    100     56.3           8.8              21.3
# 8        NaN      성별      남자    100     55.3             9              18.9
# 9        NaN     NaN      여자    100     57.3           8.6              23.4
# 10     대구광역시      전체       계    100     56.3           8.1              23.1
# ...

# %%
life_data
# Out:
#     행정구역별(1)  특성별(1)  특성별(2) 2011 2011.1 2011.2 2011.3  2011.4  2011.5 2013  \
# 0   행정구역별(1)  특성별(1)  특성별(2)    계  매우 만족  약간 만족     보통  약간 불만족  매우 불만족    계
# 1         전국      전체       계  100    5.5   18.1   48.8    20.3     7.3  100
# 2        NaN      성별      남자  100    5.9   17.9   49.3    19.6     7.3  100
# 3        NaN     NaN      여자  100    5.2   18.2   48.3      21     7.2  100
# 4      서울특별시      전체       계  100    6.3   20.4   48.8    17.1     7.4  100
# 5        NaN      성별      남자  100    6.2   19.8     50    16.6     7.3  100
# 6        NaN     NaN      여자  100    6.3     21   47.6    17.6     7.5  100
# 7      부산광역시      전체       계  100    6.4   16.3     46    22.8     8.5  100
# 8        NaN      성별      남자  100    6.7   16.2   46.3    21.7     9.1  100
# 9        NaN     NaN      여자  100    6.1   16.3   45.7    23.9       8  100
# 10     대구광역시      전체       계  100    3.2   15.2   50.9    23.7     7.1  100
# ...

# %%
culture_data.head(7, )
# Out:
#    행정구역별(1)  특성별(1)  특성별(2)   2011   2011.1        2011.2            2011.3  \
# 0  행정구역별(1)  특성별(1)  특성별(2)  계 (%)  관람함 (%)  관람횟수(평균) (회)  - 음악·연주회·콘서트 (%)
# 1        전국      전체       계    100     58.6           8.4              25.2
# 2       NaN      성별      남자    100       58           8.2              21.4
# 3       NaN     NaN      여자    100     59.2           8.7              28.7
# 4     서울특별시      전체       계    100       67           9.7              29.8
# 5       NaN      성별      남자    100     65.7           9.3              25.3
# 6       NaN     NaN      여자    100     68.3            10              33.9
#
#             2011.4            2011.5           2011.6  ...    2023.11  \
# 0  · 관람 횟수(평균) (회)  - 연극·마당극·뮤지컬 (%)  · 관람 횟수(평균) (회)  ...  - 박물관 (%)
# 1              2.5                25              2.3  ...       25.1
# 2              2.5              19.6              2.1  ...         22
# 3              2.6              30.2              2.4  ...       28.1
# ...

# %%
life_data.head(7, )
# Out:
#    행정구역별(1)  특성별(1)  특성별(2) 2011 2011.1 2011.2 2011.3  2011.4  2011.5 2013  \
# 0  행정구역별(1)  특성별(1)  특성별(2)    계  매우 만족  약간 만족     보통  약간 불만족  매우 불만족    계
# 1        전국      전체       계  100    5.5   18.1   48.8    20.3     7.3  100
# 2       NaN      성별      남자  100    5.9   17.9   49.3    19.6     7.3  100
# 3       NaN     NaN      여자  100    5.2   18.2   48.3      21     7.2  100
# 4     서울특별시      전체       계  100    6.3   20.4   48.8    17.1     7.4  100
# 5       NaN      성별      남자  100    6.2   19.8     50    16.6     7.3  100
# 6       NaN     NaN      여자  100    6.3     21   47.6    17.6     7.5  100
#
#    ... 2021.2 2021.3  2021.4  2021.5 2023 2023.1 2023.2 2023.3  2023.4  2023.5
# 0  ...  약간 만족     보통  약간 불만족  매우 불만족    계  매우 만족  약간 만족     보통  약간 불만족  매우 불만족
# 1  ...   24.2   43.1    18.1     4.8  100   11.9   30.3   43.3    11.5       3
# 2  ...   23.6   42.8    18.2     5.3  100   12.4   30.1     43    11.3     3.3
# ...

# %%
culture_data.describe().T
# Out:
#          count unique       top freq
# 행정구역별(1)    19     19  행정구역별(1)    1
# 특성별(1)      37      3        전체   18
# 특성별(2)      55      4         계   18
# 2011        55      3       100   51
# 2011.1      55     49         -    3
# ...        ...    ...       ...  ...
# 2023.16     55     18         2   10
# 2023.17   55.0   49.0      18.6  2.0
# 2023.18   55.0   28.0       4.3  9.0
# 2023.19     55     17       0.5    9
# 2023.20     55     35         1    9
#
# [138 rows x 4 columns]

# %%
life_data.describe().T
# Out:
#          count unique       top freq
# 행정구역별(1)    19     19  행정구역별(1)    1
# 특성별(1)      37      3        전체   18
# 특성별(2)      55      4         계   18
# 2011        55      3       100   51
# 2011.1    55.0   32.0       5.6  6.0
# 2011.2    55.0   39.0      16.4  4.0
# 2011.3    55.0   38.0      48.8  3.0
# 2011.4    55.0   41.0      21.5  3.0
# 2011.5    55.0   36.0       7.3  3.0
# 2013        55      3       100   51
# 2013.1    55.0   37.0      10.9  4.0
# 2013.2    55.0   41.0      23.9  3.0
# 2013.3    55.0   41.0      45.9  4.0
# 2013.4    55.0   37.0      17.2  3.0
# 2013.5    55.0   27.0       4.1  6.0
# 2015        55      2       100   54
# 2015.1    55.0   38.0      10.2  4.0
# 2015.2    55.0   41.0      22.8  3.0
# 2015.3      55     48        51    2
# 2015.4    55.0   33.0      13.5  5.0
# 2015.5    55.0   27.0       3.3  6.0
# 2017        55      2       100   54
# 2017.1    55.0   36.0       6.7  4.0
# 2017.2      55     45        23    4
# ...

# %%
culture_data.columns
# Out:
# Index(['행정구역별(1)', '특성별(1)', '특성별(2)', '2011', '2011.1', '2011.2', '2011.3',
#        '2011.4', '2011.5', '2011.6',
#        ...
#        '2023.11', '2023.12', '2023.13', '2023.14', '2023.15', '2023.16',
#        '2023.17', '2023.18', '2023.19', '2023.20'],
#       dtype='object', length=138)

# %%
life_data.columns
# Out:
# Index(['행정구역별(1)', '특성별(1)', '특성별(2)', '2011', '2011.1', '2011.2', '2011.3',
#        '2011.4', '2011.5', '2013', '2013.1', '2013.2', '2013.3', '2013.4',
#        '2013.5', '2015', '2015.1', '2015.2', '2015.3', '2015.4', '2015.5',
#        '2017', '2017.1', '2017.2', '2017.3', '2017.4', '2017.5', '2019',
#        '2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2021', '2021.1',
#        '2021.2', '2021.3', '2021.4', '2021.5', '2023', '2023.1', '2023.2',
#        '2023.3', '2023.4', '2023.5'],
#       dtype='object')

# %%
#문화예술 데이터 정보
print("데이터 크기:", culture_data.shape)
print("\n데이터 정보:")
culture_data.info()
# Out:
# 데이터 크기: (55, 138)
#
# 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Columns: 138 entries, 행정구역별(1) to 2023.20
# dtypes: object(138)
# memory usage: 59.4+ KB

# %%
#삶의 만족도 데이터 정보
print("데이터 크기:", life_data.shape)
print("\n데이터 정보:")
life_data.info()
# Out:
# 데이터 크기: (55, 45)
#
# 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 45 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   행정구역별(1)  19 non-null     object
#  1   특성별(1)    37 non-null     object
#  2   특성별(2)    55 non-null     object
#  3   2011      55 non-null     object
#  4   2011.1    55 non-null     object
#  5   2011.2    55 non-null     object
#  6   2011.3    55 non-null     object
#  7   2011.4    55 non-null     object
#  8   2011.5    55 non-null     object
#  9   2013      55 non-null     object
#  10  2013.1    55 non-null     object
#  11  2013.2    55 non-null     object
#  12  2013.3    55 non-null     object
#  13  2013.4    55 non-null     object
#  14  2013.5    55 non-null     object
#  15  2015      55 non-null     object
#  16  2015.1    55 non-null     object
#  17  2015.2    55 non-null     object
#  18  2015.3    55 non-null     object
# ...

# %% [markdown]
# **데이터 전처리**
#
# ---
